, 769, 774, 777, 780, 784, 785, 792, 793, 795, 801, 802, 806, 808, 810, 815, 816, 818, 819, 820, 821, 822, 824, 826, 827, 828, 829, 830, 831, 832, 834, 835, 836, 837, 838, 839, 842, 845, 846, 847, 848, 849, 850, 852, 853, 856, 857, 858, 859, 860, 862, 863, 865, 866, 870, 873, 874, 875, 876, 877, 878, 881, 885, 886, 887, 888, 889, 890, 891, 894, 895, 897, 898, 899, 900, 901, 902, 903, 904, 905, 906, 907, 908, 909, 910, 913, 914, 915, 918, 919, 920, 921, 922, 925, 926, 927, 928, 929, 930, 932, 933, 934, 936, 940, 941, 942, 943, 944, 945, 946, 947, 949, 950, 951, 952, 953, 954, 955, 963, 964, 966, 967, 968, 969, 970, 971, 974, 977, 978, 979, 981, 983, 984, 985, 997, 998, 1002, 1003, 1004, 1005, 1007, 1009, 1010, 1011, 1013, 1020, 1026, 1027, 1028, 1029, 1031, 1032, 1033, 1034, 1035, 1036, 1039, 1040, 1041, 1043, 1045, 1046, 1047, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1063, 1064, 1065, 1066, 1071, 1072, 10 ...

# %%
import jieba
import re
from zhon.hanzi import punctuation
from nltk.corpus import stopwords
punctuations = list(punctuation)
stopword = [line.strip().replace('\n','') for line in open('../hw1/stopwords.txt','r').readlines()]
punctuations = [line.strip().replace('\n','') for line in open('../hw1/punctuation.txt','r').readlines()]
jieba.load_userdict('../hw1/userDict.txt')
stop_words = stopwords.words("chinese")

# %%
def preprocess(data):
    data = re.sub('[^\u4e00-\u9fa5]','',data)
    info = data.replace('\n','').replace('\t','').replace('\u3000','')
    info = jieba.lcut(info)
    Info = [i for i in list(info) if i not in stopword]
    Info = [i for i in list(info) if i not in stop_words]
    return Info

# %%
DATA =[]
labels = []
for movie in movie_info[:6000]:
    info = preprocess(movie['intro'])
    info = [" ".join(info)]
    info.insert(0,movie['label[class]'][0] if len(movie['label[class]'])>0 else "NA")
    labels.append(movie['label[class]'][0] if len(movie['label[class]'])>0 else "NA")
    DATA.append(info)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
train_x = [data[1] for data in DATA]
train_y = [data[0] for data in DATA]
TFIDF = TfidfVectorizer(token_pattern =r"(?u)\b\w\w+\b")
train_X = TFIDF.fit_transform(train_x)
train_X = TFIDF.transform(train_x)

# %%
label_class = list(dict.fromkeys(labels))
print(label_class)
# Out:
# ['劇情', '動作', '喜劇', '冒險', '奇幻', '愛情', '溫馨/家庭', '科幻', '犯罪', '戰爭', '紀錄片', '懸疑/驚悚', '動畫', '恐怖', '勵志', '歷史/傳記', '音樂/歌舞', 'NA']

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
svm_clf = SVC()
svm_clf.fit(train_X, train_y)
print(f"SVM score, cross validated:   {np.mean(cross_val_score(svm_clf, train_X, train_y,cv=12)):.3f}")

# %%
from sklearn.naive_bayes import MultinomialNB
naive_bayes_classifier = MultinomialNB()
naive_bayes_classifier.fit(train_X, train_y)
print(f"SVM score, cross validated:   {np.mean(cross_val_score(naive_bayes_classiffier, train_X, train_y,cv=12)):.3f}")
# Out:
#               precision    recall  f1-score   support
#
#           劇情       0.00      0.00      0.00        12
#           動作       0.00      0.00      0.00         5
#           喜劇       0.43      1.00      0.61       216
#           冒險       0.50      0.01      0.03        73
#           奇幻       0.00      0.00      0.00        22
#           愛情       0.00      0.00      0.00         3
#        溫馨/家庭       0.00      0.00      0.00        16
#           科幻       0.00      0.00      0.00        11
#           犯罪       0.00      0.00      0.00        44
#           戰爭       0.00      0.00      0.00        18
#          紀錄片       0.00      0.00      0.00        18
#        懸疑/驚悚       0.00      0.00      0.00         2
#           動畫       0.00      0.00      0.00         1
#           恐怖       0.00      0.00      0.00         2
#           勵志       0.00      0.00      0.00         4
#        歷史/傳記       0.00      0.00      0.00        11
#        音樂/歌舞       0.00      0.00      0.00        31
#           NA       0.00      0.00      0.00        11
#
#     accuracy                           0.43       500
#    macro avg       0.05      0.06      0.04       500
# weighted avg       0.26      0.43      0.27       500
# /Users/kaichengliu/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/kaichengliu/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/kaichengliu/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors=5)
print("Training KNN...")
KNN.fit(train_X, train_y)
print("Predicting KNN...")
y_pred = KNN.predict(test_X)
# Out:
# Training KNN...
# Predicting KNN...

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print(classification_report(test_y, y_pred, target_names=label_class))
# Out:
#               precision    recall  f1-score   support
#
#           劇情       0.33      0.08      0.13        12
#           動作       0.00      0.00      0.00         5
#           喜劇       0.46      0.99      0.63       216
#           冒險       0.85      0.23      0.37        73
#           奇幻       0.00      0.00      0.00        22
#           愛情       0.00      0.00      0.00         3
#        溫馨/家庭       0.00      0.00      0.00        16
#           科幻       0.00      0.00      0.00        11
#           犯罪       1.00      0.02      0.04        44
#           戰爭       0.00      0.00      0.00        18
#          紀錄片       0.00      0.00      0.00        18
#        懸疑/驚悚       0.00      0.00      0.00         2
#           動畫       0.00      0.00      0.00         1
#           恐怖       0.00      0.00      0.00         2
#           勵志       0.00      0.00      0.00         4
#        歷史/傳記       0.00      0.00      0.00        11
#        音樂/歌舞       1.00      0.19      0.32        31
#           NA       1.00      0.09      0.17        11
#
#     accuracy                           0.48       500
#    macro avg       0.26      0.09      0.09       500
# weighted avg       0.50      0.48      0.35       500
# /Users/kaichengliu/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/kaichengliu/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/kaichengliu/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn import ensemble

RF = ensemble.RandomForestClassifier(n_estimators = 100)
print("Training RF...")
RF.fit(train_X, train_y)
print("Predicting RF...")
y_pred = RF.predict(test_X)
# Out:
# Training RF...
# Predicting RF...

# %%
print(classification_report(test_y, y_pred, target_names=label_class))
# Out:
#               precision    recall  f1-score   support
#
#           劇情       0.00      0.00      0.00        12
#           動作       0.00      0.00      0.00         5
#           喜劇       0.49      0.97      0.65       216
#           冒險       0.65      0.51      0.57        73
#           奇幻       1.00      0.09      0.17        22
#           愛情       0.00      0.00      0.00         3
#        溫馨/家庭       0.00      0.00      0.00        16
#           科幻       0.00      0.00      0.00        11
#           犯罪       0.79      0.25      0.38        44
#           戰爭       0.00      0.00      0.00        18
#          紀錄片       0.00      0.00      0.00        18
#        懸疑/驚悚       0.00      0.00      0.00         2
#           動畫       0.00      0.00      0.00         1
#           恐怖       0.00      0.00      0.00         2
#           勵志       0.00      0.00      0.00         4
#        歷史/傳記       0.00      0.00      0.00        11
#        音樂/歌舞       0.00      0.00      0.00        31
#           NA       0.00      0.00      0.00        11
#
#     accuracy                           0.52       500
#    macro avg       0.16      0.10      0.10       500
# weighted avg       0.42      0.52      0.41       500
# /Users/kaichengliu/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/kaichengliu/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/kaichengliu/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
